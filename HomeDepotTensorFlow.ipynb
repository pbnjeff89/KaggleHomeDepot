# %% [markdown]
# # Using TensorFlow to Find the Relevance of Search Queries

# %% [markdown]
# ## Initial procedures

# %%
import pandas as pd
import matplotlib as mpl
import numpy as np
import math
import os

# %%
folder = '/home/pbnjeff/Dropbox/KaggleHomeDepotData/'
cleaned_data_path = '/home/pbnjeff/Dropbox/KaggleHomeDepotData/combined_cleaned.csv'

train_path = folder + 'train.csv'
test_path = folder + 'test.csv'

train = pd.read_csv(train_path)
test = pd.read_csv(test_path)

if os.path.exists(cleaned_data_path):
    combined = pd.read_csv(cleaned_data_path)
else:
    combined = train.append(test)
    combined = combined.reset_index(drop=True)

# %%
attributes = pd.read_csv('/home/pbnjeff/Dropbox/KaggleHomeDepotData/attributes.csv')

# %% [markdown]
# ## Feature engineering

# %%
def breakDownQueryNames(df):
    
    # Lowercase for everything to normalize
    df['query_terms'] = df['search_term'].str.lower()
    df['query_terms'] = df['search_term'].str.replace('-',' ')
    df['productname_terms'] = df['product_title'].str.lower()
    df['productname_terms'] = df['productname_terms'].replace('-',' ')
    df['query_terms'] = df['query_terms'].str.split(' ')
    df['productname_terms'] = df['productname_terms'].str.split(' ')
    
    return df

def removeLists(df):
    """
    Helper function to remove unnecessary columns for training models
    """
    
    return df.drop(['query_terms','productname_terms','material_terms'],axis=1)

def percentQueryInProductName(df):
    
    
    df['percentQueryInName'] = pd.Series()
    
    for i in range(len(df['query_terms'])):

        numQueryTerms = len(df['query_terms'][i])
        numNameTerms = len(df['productname_terms'][i])
        queryTermsInName = 0

        for j in range(numQueryTerms):

            if df['query_terms'][i][j] in df['productname_terms'][i]:

                queryTermsInName += 1

        df.loc[i,'percentQueryInName'] = float(queryTermsInName) / numNameTerms
        
        printCompleted(i, len(df['query_terms']))
    
    return df

def printCompleted(i, total):
    
    if i % 10000 == 0:
        
        print('{0}'.format(str(i) + '/' + str(total) + ' completed!'))

def hasOneMatch(df):
    
    df['hasMatch'] = pd.Series()
    
    for i in range(len(df['query_terms'])):
        
        numQueryTerms = len(df['query_terms'][i])
        queryTermInName = False

        for j in range(numQueryTerms):

            if df['query_terms'][i][j] in df['productname_terms'][i]:

                queryTermInName = True

        df.loc[i,'hasMatch'] = queryTermInName
        
        printCompleted(i, len(df['query_terms']))
    
    return df

def isNumber(string):
    
    try:
        float(string)
        return True
    except ValueError:
        return False

def queryProductHaveNumeric(df):
    """
    Humans might input the wrong number, but the intention
    was to specify a number. This is a measure of whether
    a human had the intention.
    """
    
    df['BothHaveNumbers'] = pd.Series()
    
    for i in range(len(df['query_terms'])):
        
        queryNumber = False
        productNumber = False

        for word in df['query_terms'][i]:

            if isNumber(str(word)):

                queryNumber = True

        for word in df['productname_terms'][i]:

            if isNumber(str(word)):

                productNumber = True

        if (queryNumber and productNumber):

            df['BothHaveNumbers'] = True

        else:

            df['BothHaveNumbers'] = False
            
        printCompleted(i, len(df['query_terms']))

    return df

def materialHasMatch(df):
    
    df['MaterialMatch'] = pd.Series()
    
    for i in range(len(df['query_terms'])):
        
        hasMatch = False
        
        for term in df['query_terms'][i]:
            
            if term in df['material_terms'][i]:

                hasMatch = True
        
        df['MaterialMatch'][i] = hasMatch
        
        printCompleted(i, len(df['query_terms']))
    
    return df

def percentMaterialMatched(df):
    
    df['percentMaterialMatched'] = pd.Series()

    for i in range(len(df['query_terms'])):
        
        numMatches = 0
        numMaterialTerms = len(df['material_terms'][i])

        for term in df['query_terms'][i]:

            if term in df['material_terms'][i]:

                numMatches += 1

        if numMatches > numMaterialTerms:
            numMatches = numMaterialTerms

        df['percentMaterialMatched'][i] = float(numMatches) / numMaterialTerms

        printCompleted(i, len(df['query_terms']))
    
    return df

def getMaterials(attributes, df):
    
    uid_materials = attributes.loc[attributes['name'] == 'Material'].drop('name', axis=1).reset_index(drop=True)
    
    df['material_terms'] = pd.Series()
    uid_materials['material_terms'] = uid_materials['value'].str.lower()
    uid_materials['materials'] = uid_materials['material_terms'].str.split(' ')
    uid_materials = uid_materials.drop('material_terms', axis=1)
    
    for i in range(len(df['product_uid'])):
        
        uid = df['product_uid'][i]
        mat_df = uid_materials[uid_materials['product_uid']==uid]['materials'].to_frame()
        
        try:
            material_terms = mat_df.iloc[0]['materials']
        except IndexError:
            material_terms = ['']
            
        df['material_terms'][i] = material_terms
        
        try:
            if math.isnan(df['material_terms'][i]):
                df['material_terms'][i] = ['']
        except:
            pass
        
        # TODO: Eliminate the parenthesis surrounding things like '(mdf)'
        
    return df

# %%
combined = breakDownQueryNames(combined)

# %%
combined = percentQueryInProductName(combined)
# Out:
# 0/240760 completed!
# 10000/240760 completed!
# 20000/240760 completed!
# 30000/240760 completed!
# 40000/240760 completed!
# 50000/240760 completed!
# 60000/240760 completed!
# 70000/240760 completed!
# 80000/240760 completed!
# 90000/240760 completed!
# 100000/240760 completed!
# 110000/240760 completed!
# 120000/240760 completed!
# 130000/240760 completed!
# 140000/240760 completed!
# 150000/240760 completed!
# 160000/240760 completed!
# 170000/240760 completed!
# 180000/240760 completed!
# 190000/240760 completed!
# 200000/240760 completed!
# 210000/240760 completed!
# 220000/240760 completed!
# 230000/240760 completed!
# 240000/240760 completed!

# %%
combined = hasOneMatch(combined)
# Out:
# 0/240760 completed!
# 10000/240760 completed!
# 20000/240760 completed!
# 30000/240760 completed!
# 40000/240760 completed!
# 50000/240760 completed!
# 60000/240760 completed!
# 70000/240760 completed!
# 80000/240760 completed!
# 90000/240760 completed!
# 100000/240760 completed!
# 110000/240760 completed!
# 120000/240760 completed!
# 130000/240760 completed!
# 140000/240760 completed!
# 150000/240760 completed!
# 160000/240760 completed!
# 170000/240760 completed!
# 180000/240760 completed!
# 190000/240760 completed!
# 200000/240760 completed!
# 210000/240760 completed!
# 220000/240760 completed!
# 230000/240760 completed!
# 240000/240760 completed!

# %%
combined = queryProductHaveNumeric(combined)
# Out:
# 0/240760 completed!
# 10000/240760 completed!
# 20000/240760 completed!
# 30000/240760 completed!
# 40000/240760 completed!
# 50000/240760 completed!
# 60000/240760 completed!
# 70000/240760 completed!
# 80000/240760 completed!
# 90000/240760 completed!
# 100000/240760 completed!
# 110000/240760 completed!
# 120000/240760 completed!
# 130000/240760 completed!
# 140000/240760 completed!
# 150000/240760 completed!
# 160000/240760 completed!
# 170000/240760 completed!
# 180000/240760 completed!
# 190000/240760 completed!
# 200000/240760 completed!
# 210000/240760 completed!
# 220000/240760 completed!
# 230000/240760 completed!
# 240000/240760 completed!

# %%
combined = getMaterials(attributes, combined)

# %%
combined = materialHasMatch(combined)
# Out:
# 0/240760 completed!
# 10000/240760 completed!
# 20000/240760 completed!
# 30000/240760 completed!
# 40000/240760 completed!
# 50000/240760 completed!
# 60000/240760 completed!
# 70000/240760 completed!
# 80000/240760 completed!
# 90000/240760 completed!
# 100000/240760 completed!
# 110000/240760 completed!
# 120000/240760 completed!
# 130000/240760 completed!
# 140000/240760 completed!
# 150000/240760 completed!
# 160000/240760 completed!
# 170000/240760 completed!
# 180000/240760 completed!
# 190000/240760 completed!
# 200000/240760 completed!
# 210000/240760 completed!
# 220000/240760 completed!
# 230000/240760 completed!
# 240000/240760 completed!

# %%
combined = percentMaterialMatched(combined)
# Out:
# 0/240760 completed!
# 10000/240760 completed!
# 20000/240760 completed!
# 30000/240760 completed!
# 40000/240760 completed!
# 50000/240760 completed!
# 60000/240760 completed!
# 70000/240760 completed!
# 80000/240760 completed!
# 90000/240760 completed!
# 100000/240760 completed!
# 110000/240760 completed!
# 120000/240760 completed!
# 130000/240760 completed!
# 140000/240760 completed!
# 150000/240760 completed!
# 160000/240760 completed!
# 170000/240760 completed!
# 180000/240760 completed!
# 190000/240760 completed!
# 200000/240760 completed!
# 210000/240760 completed!
# 220000/240760 completed!
# 230000/240760 completed!
# 240000/240760 completed!

# %%
combined.head(1)
# Out:
#    id                      product_title  product_uid  relevance  \
# 0   2  Simpson Strong-Tie 12-Gauge Angle       100001          3
#
#      search_term           query_terms  \
# 0  angle bracket  ['angle', 'bracket']
#
#                                 productname_terms  percentQueryInName  \
# 0  ['simpson', 'strong-tie', '12-gauge', 'angle']                0.25
#
#   hasMatch BothHaveNumbers  MaterialMatch  percentMaterialMatched  \
# 0     True            True              0                       0
#
#             material_terms
# 0  ['galvanized', 'steel']
#
# [1 rows x 13 columns]

# %%
combined.to_csv(cleaned_data_path, index=False)

# %%
combined = removeLists(combined)

# %%
combined
# Out:
#      id                                      product_title  product_uid  \
# 0     2                  Simpson Strong-Tie 12-Gauge Angle       100001
# 1     3                  Simpson Strong-Tie 12-Gauge Angle       100001
# 2     9  BEHR Premium Textured DeckOver 1-gal. #SC-141 ...       100002
# 3    16  Delta Vero 1-Handle Shower Only Faucet Trim Ki...       100005
# 4    17  Delta Vero 1-Handle Shower Only Faucet Trim Ki...       100005
# 5    18  Whirlpool 1.9 cu. ft. Over the Range Convectio...       100006
# 6    20  Whirlpool 1.9 cu. ft. Over the Range Convectio...       100006
# 7    21  Whirlpool 1.9 cu. ft. Over the Range Convectio...       100006
# 8    23  Lithonia Lighting Quantum 2-Light Black LED Em...       100007
# 9    27  House of Fara 3/4 in. x 3 in. x 8 ft. MDF Flut...       100009
# 10   34       Valley View Industries Metal Stakes (4-Pack)       100010
# 11   35  Toro Personal Pace Recycler 22 in. Variable Sp...       100011
# 12   37  Toro Personal Pace Recycler 22 in. Variable Sp...       100011
# 13   38  Toro Personal Pace Recycler 22 in. Variable Sp...       100011
# 14   48  Hampton Bay Caramel Simple Weave Bamboo Rollup...       100012
# 15   51  InSinkErator SinkTop Switch Single Outlet for ...       100013
# 16   65  Sunjoy Calais 8 ft. x 5 ft. x 8 ft. Steel Tile...       100016
# 17   69  MD Building Products 36 in. x 36 in. Cloverlea...       100017
# 18   75  MD Building Products 36 in. x 36 in. Cloverlea...       100017
# 19   81  MD Building Products 36 in. x 36 in. Cloverlea...       100017
# 20   85  MD Building Products 36 in. x 36 in. Cloverlea...       100017
# 21   88  House of Fara 8 Linear ft. MDF Overlapping Wai...       100019
# 22   90  House of Fara 8 Linear ft. MDF Overlapping Wai...       100019
# 23   92  House of Fara 8 Linear ft. MDF Overlapping Wai...       100019
# 24  101  House of Fara 8 Linear ft. MDF Overlapping Wai...       100019
# 25  105  House of Fara 8 Linear ft. MDF Overlapping Wai...       100019
# 26  106  House of Fara 8 Linear ft. MDF Overlapping Wai...       100019
# 27  113  1804 Dual Spray Half Pattern 4 in Pop-Up Spray...       100021
# 28  114  1804 Dual Spray Half Pattern 4 in Pop-Up Spray...       100021
# 29  117  Samsung 4.2 cu. ft. Front Load Washer with Ste...       100022
# 30  120  Samsung 4.2 cu. ft. Front Load Washer with Ste...       100022
# 31  122  Samsung 4.2 cu. ft. Front Load Washer with Ste...       100022
# 32  123           Quikrete 80 lb. Crack-Resistant Concrete       100023
# 33  125           Quikrete 80 lb. Crack-Resistant Concrete       100023
# 34  127           Quikrete 80 lb. Crack-Resistant Concrete       100023
# 35  136  Nantucket Pavers Patio-on-a-Pallet 10 ft. x 10...       100026
# 36  138  Nantucket Pavers Patio-on-a-Pallet 10 ft. x 10...       100026
# 37  143         UltraTouch 48 in. x 24 ft. Radiant Barrier       100027
# 38  147  Backyard X-Scapes 6 ft. H. x 16 ft. L Reed Fen...       100028
# 39  149  Backyard X-Scapes 6 ft. H. x 16 ft. L Reed Fen...       100028
# 40  150  Backyard X-Scapes 6 ft. H. x 16 ft. L Reed Fen...       100028
# 41  157  Backyard X-Scapes 6 ft. H. x 16 ft. L Reed Fen...       100028
# 42  158  Backyard X-Scapes 6 ft. H. x 16 ft. L Reed Fen...       100028
# 43  162  DecoArt Americana Decor 16-oz. Whisper Chalky ...       100029
# 44  164     9.1 in. x 5.8 in. White Designer Shelf Bracket       100030
# 45  165     9.1 in. x 5.8 in. White Designer Shelf Bracket       100030
# 46  166     9.1 in. x 5.8 in. White Designer Shelf Bracket       100030
# 47  172  HDX 48 in. W x 72 in. H x 18 in. D Decorative ...       100033
# 48  177  HDX 48 in. W x 72 in. H x 18 in. D Decorative ...       100033
# 49  178  HDX 48 in. W x 72 in. H x 18 in. D Decorative ...       100033
# 50  179  HDX 48 in. W x 72 in. H x 18 in. D Decorative ...       100033
# 51  181  HDX 48 in. W x 72 in. H x 18 in. D Decorative ...       100033
# 52  182  HDX 48 in. W x 72 in. H x 18 in. D Decorative ...       100033
# 53  186  HDX 48 in. W x 72 in. H x 18 in. D Decorative ...       100033
# 54  191  HDX 48 in. W x 72 in. H x 18 in. D Decorative ...       100033
# 55  193  HDX 48 in. W x 72 in. H x 18 in. D Decorative ...       100033
# 56  195                         Marshalltown Masonry Brush       100034
# 57  201           Rubbermaid 12 in. D Single Track Bracket       100036
# 58  202           Rubbermaid 12 in. D Single Track Bracket       100036
# 59  203           Rubbermaid 12 in. D Single Track Bracket       100036
#     ...                                                ...          ...
#
#     relevance                             search_term  percentQueryInName  \
# 0        3.00                           angle bracket            0.250000
# 1        2.50                               l bracket            0.000000
# 2        3.00                               deck over            0.000000
# 3        2.33                        rain shower head            0.076923
# 4        2.67                      shower only faucet            0.230769
# 5        3.00                          convection otr            0.066667
# 6        2.67                    microwave over stove            0.133333
# 7        3.00                              microwaves            0.000000
# 8        2.67                         emergency light            0.111111
# 9        3.00                                 mdf 3/4            0.142857
# 10       2.67                            steele stake            0.000000
# 11       3.00          briggs and stratton lawn mower            0.235294
# 12       3.00                                gas mowe            0.058824
# 13       2.00                             honda mower            0.058824
# 14       2.67      hampton bay chestnut pull up shade            0.187500
# 15       2.67                                disposer            0.000000
# 16       3.00                            grill gazebo            0.133333
# 17       1.00                             door guards            0.000000
# 18       1.67                  metal plate cover gcfi            0.000000
# 19       2.33                          radiator grate            0.000000
# 20       2.33                         windows screens            0.000000
# 21       1.33                1x1 rail decorative wood            0.000000
# 22       2.67                  4*8 beadboard paneling            0.083333
# 23       2.33                        4x8wood paneling            0.083333
# 24       1.33                                 MDF 4x8            0.000000
# 25       2.33                     wainscot chair rail            0.083333
# 26       2.33                 wainscot plank paneling            0.166667
# 27       2.00                          lawn sprkinler            0.000000
# 28       2.33                      rainbird sprinkler            0.000000
# 29       2.67                    PLATFORM FOR WASHERS            0.000000
# 30       2.00           samsung front load washer 3.7            0.307692
# 31       2.33  upholstery washing machines with steam            0.153846
# 32       3.00     CONCRETE & MASONRY CLEANER & ETCHER            0.000000
# 33       2.00                      concrete for ponds            0.200000
# 34       2.00                     flexlock for cracks            0.000000
# 35       2.00                    Belgium block pavers            0.071429
# 36       2.33                      ourdoor patio tile            0.000000
# 37       2.33                         insulation roll            0.000000
# 38       2.00                    6ft h bamboo fencing            0.090909
# 39       2.67                  balcony privacy screen            0.000000
# 40       1.67                                  bamboo            0.000000
# 41       2.33                  privacy lattice panels            0.000000
# 42       1.67                          privacy panels            0.000000
# 43       3.00                             chalk paint            0.000000
# 44       1.67                          8 4616809045 9            0.000000
# 45       3.00                           shelf bracket            0.222222
# 46       1.67                          white 4shelves            0.111111
# 47       3.00                         6 teir shelving            0.052632
# 48       3.00                       hdx wire shelving            0.157895
# 49       1.00               kitchen  cabinet finishes            0.000000
# 50       3.00               kitchen wire shelf tiered            0.052632
# 51       2.67                             pantry rack            0.000000
# 52       2.67                   plastic storage racks            0.000000
# 53       3.00                           Shelves Metal            0.000000
# 54       2.67                          steel shelving            0.052632
# 55       3.00                          storage shelve            0.000000
# 56       1.00                            mortar tools            0.000000
# 57       2.33                     12 boltless bracket            0.285714
# 58       2.33     12 in.  16 in single track brackets            0.571429
# 59       3.00                   12 wire shelf bracket            0.285714
#           ...                                     ...                 ...
#
#    hasMatch BothHaveNumbers  MaterialMatch  percentMaterialMatched
# 0      True            True              0                       0
# 1     False            True              0                       0
# 2     False            True              0                       0
# 3      True            True              0                       0
# 4      True            True              0                       0
# 5      True            True              0                       0
# 6      True            True              0                       0
# 7     False            True              0                       0
# 8      True            True              0                       0
# 9      True            True              0                       0
# 10    False            True              0                       0
# 11     True            True              0                       0
# 12     True            True              0                       0
# 13     True            True              0                       0
# 14     True            True              0                       0
# 15    False            True              0                       0
# 16     True            True              0                       0
# 17    False            True              0                       0
# 18    False            True              0                       0
# 19    False            True              0                       0
# 20    False            True              0                       0
# 21    False            True              0                       0
# 22     True            True              0                       0
# 23     True            True              0                       0
# 24    False            True              0                       0
# 25     True            True              0                       0
# 26     True            True              0                       0
# 27    False            True              0                       0
# 28    False            True              0                       0
# 29    False            True              0                       0
# 30     True            True              0                       0
# 31     True            True              0                       0
# 32    False            True              0                       0
# 33     True            True              1                       1
# 34    False            True              0                       0
# 35     True            True              0                       0
# 36    False            True              0                       0
# 37    False            True              0                       0
# 38     True            True              0                       0
# 39    False            True              0                       0
# 40    False            True              0                       0
# 41    False            True              0                       0
# 42    False            True              0                       0
# 43    False            True              0                       0
# 44    False            True              0                       0
# 45     True            True              0                       0
# 46     True            True              0                       0
# 47     True            True              0                       0
# 48     True            True              1                       1
# 49    False            True              0                       0
# 50     True            True              1                       1
# 51    False            True              0                       0
# 52    False            True              0                       0
# 53    False            True              0                       0
# 54     True            True              0                       0
# 55    False            True              0                       0
# 56    False            True              0                       0
# 57     True            True              0                       0
# 58     True            True              0                       0
# 59     True            True              0                       0
#         ...             ...            ...                     ...
#
# [240760 rows x 10 columns]
